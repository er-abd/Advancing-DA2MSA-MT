# %% [markdown]
# [link text](https://)To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# **Read our [blog post](https://unsloth.ai/blog/r1-reasoning) for guidance on how to train reasoning models.**
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab and Kaggle notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29 peft trl triton
    # !pip install --no-deps cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf datasets huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
# FastLanguageModel is an optimized way to load models.
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048  # Choose any! We auto support RoPE Scaling internally!

# this is for precision
dtype = (
    None  # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
)
load_in_4bit = True  # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no  out-of-memory (OOMs) errors.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",  # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",  # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit",  # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",  # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",  # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",  # Gemma 2x faster!
]  # More models at https://huggingface.co/unsloth


# load the model and tokanizer
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/gemma-2-27b",
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf -  some models require an authentication token to access them.
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: If you want to finetune Gemma 2, install flash-attn to make it faster!
# To install flash-attn, do the below:
#
# pip install --no-deps --upgrade "flash-attn>=2.6.3"
# ==((====))==  Unsloth 2025.2.15: Fast Gemma2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/199k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/7.94G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/7.86G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/46.4k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
# Adding LoRA Adapters - it just modifies the already-loaded model to prepare it for efficient fine-tuning. - gets the peft_model
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",], #For best performance, keep all 7 layers as in the code.

    lora_alpha = 16, # 8 or 16 for a balance between stability and effectiveness - Higher values (e.g., 32) can lead to overfitting in small datasets.
    lora_dropout = 0, # Supports any, but = 0 (good for stable models and large datasets) is optimized - For small datasets, try lora_dropout = 0.05 or 0.1 to prevent overfitting. - If fine-tuning on large datasets, keeping it at 0 is fine.
    bias = "none",    # Supports any, but = "none" is optimized - Controls whether biases are trainable in LoRA layers - options: none, all, lora_only
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context - Saves GPU memory when training long sequences.
    random_state = 3407, # If reproducibility is important, keep it.
    use_rslora = False,  # We support rank stabilized LoRA - I think "Keep it False unless fine-tuning very large models (>30B parameters) & if LoRA model converges too slowly, try setting it to True"
    loftq_config = None, # And LoftQ - unless  fine-tune on low-memory hardware, keep it as None
)
# Out:
# Unsloth 2025.2.15 patched 46 layers with 46 QKV layers, 46 O layers and 46 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `llama-3` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/drive/1XamvWYinY6FOSX9GLvnqSjjsNflxdhNc?usp=sharing).
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing).

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from datasets import Dataset

# Define the EOS token
EOS_TOKEN = tokenizer.eos_token

# Define the prompt format
alpaca_prompt = """Translate the below text from Dialectal Arabic to Modern Standard Arabic:

### DA text:
{}

### MSA translation:
{}"""

# Load the dataset from Google Drive
csv_path = ""
df = pd.read_csv(csv_path, header=0)  # Ensure header=0 if the first row contains column names

# Define function to format the dataset
def formatting_prompts_func(examples):
    return {
        "text": [
            alpaca_prompt.format(da, msa) + EOS_TOKEN
            for da, msa in zip(examples["DA"], examples["MSA"])
        ]
    }

# Convert Pandas DataFrame to Hugging Face Dataset
dataset = Dataset.from_pandas(df)

# Apply formatting function
dataset = dataset.map(formatting_prompts_func, batched=True)

# Print first example to verify formatting
print(dataset[0])
# Out:
# Map:   0%|          | 0/62775 [00:00<?, ? examples/s]
# {'Dialect': 'EGY', 'DA': 'عاجبني البلوفر بتاعك.', 'MSA': 'أحب الجاكت الخاص بك .', 'text': 'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعاجبني البلوفر بتاعك.\n\n### MSA translation:\nأحب الجاكت الخاص بك .<eos>'}

# %%
print(dataset["text"][0])
# Out:
# Translate the below text from Dialectal Arabic to Modern Standard Arabic:
#
# ### DA text:
# عاجبني البلوفر بتاعك.
#
# ### MSA translation:
# أحب الجاكت الخاص بك .<eos>

# %%
dataset
# Out:
# Dataset({
#     features: ['Dialect', 'DA', 'MSA', 'text'],
#     num_rows: 62775
# })

# %%
dataset['text']
# Out:
# ['Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعاجبني البلوفر بتاعك.\n\n### MSA translation:\nأحب الجاكت الخاص بك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلا مستحيل احكي هيك\n\n### MSA translation:\nلا من المستحيل أن أتكلم هكذا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعلى الشمال، لو سمحت.\n\n### MSA translation:\nإلى اليسار ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفيك تحط تخت زيادة بالأوضة؟\n\n### MSA translation:\nهل من الممكن أن تضع سريرا إضافيا في الغرفة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكتير هيك.\n\n### MSA translation:\nإنه كثير جداً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك واين من كاليفورنيا؟\n\n### MSA translation:\nهل لديك أي نبيذ كاليفورني ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت صورني.\n\n### MSA translation:\nمن فضلك التقط صورة لي .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتقدر تصلح هالكاميرا؟\n\n### MSA translation:\nهل يمكنك إصلاح هذه الكاميرا ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تنضف الهدوم ديه؟\n\n### MSA translation:\nهل لك أن تقوم بتنظيف هذه الملابس ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتايري فاش.\n\n### MSA translation:\nعندي إطار فارغ من الهواء .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالفاشلون فى الحب هم فقط من يحبون بضمير\n\n### MSA translation:\nالفاشلون في الحب هم فقط من يحبون بضمير<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتهجاها لو سمحت.\n\n### MSA translation:\nتهجى الكلمة من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمكتب الاستقبال فين؟\n\n### MSA translation:\nأين مكتب الاستقبال ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنظري ضعيف.\n\n### MSA translation:\nأعاني من ضعف الإبصار .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاكتر كلمة بضحكنى الضحك من غير سبب قلة ادب ده على فكرة بضحكنى اكتر مش بتكسفني\n\n### MSA translation:\nأكثر شئ يبهجنى هو الأبتسام بدون أسباب قله أحترام وهذا يجعلنى أبتسم أكثر لا أخجل<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن آخد شوية فيتامينات؟\n\n### MSA translation:\nهل يمكنني الحصول علي بعض الفيتامينات ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي مع ساعد يد تانية.\n\n### MSA translation:\nأريد ساعة مستعملة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nابغي شوية قهوة.\n\n### MSA translation:\nأود بعض القهوة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي ياه لفرصة أخر الجمعة .\n\n### MSA translation:\nأريدها لعطلة نهاية الأسبوع .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين بلاقي القسم اللغز؟\n\n### MSA translation:\nأين سأجد قسم الألغاز ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمخلوط، مش متقلب.\n\n### MSA translation:\nمهزوز ، وليس مضروب .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلكن مو المطاعم اليابانية في كيوتو غالية؟\n\n### MSA translation:\nأليست المطاعم اليابانية في كيوتو غالية ، بالرغم من ذلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانه شو جاب عبالي عيد هيك مسلسل كئيب زهرة النرجس\n\n### MSA translation:\nما الذي جعلني أفكر في إعادة مشاهدة هذا المسلسل الكئيب زهرة النرجس<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمقابلتك شيء لطيف جدا.\n\n### MSA translation:\nكان من اللطيف جدا أن أقابلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nان شاء الله كل شي يصير اوكي.\n\n### MSA translation:\nأتمنى أن تكون جميلة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمعلش نبدا نلعب بس يخلصوا؟\n\n### MSA translation:\nهل يمكن أن نبدأ اللعب عندما ينتهون ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاحسنلك تطلب قسم المفقودات.\n\n### MSA translation:\nيفضل أن تتصل بقسم " المفقودات و الأشياء التي عثر عليها . "<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهي أول روحة إلي ع باريس.\n\n### MSA translation:\nهذه هي رحلتي الأولى إلى باريس .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن اطلب كاس واين؟\n\n### MSA translation:\nهل يمكن أن أطلب كأس نبيذ ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاظن ان رقم التكسي كان واحد اثنين ثلاثة اربعة خمسة.\n\n### MSA translation:\nأعتقد أن رقم التاكسي كان واحد أثنين ثلاثة أربع خمس .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانبسطت اليوم بوقتي المسا . شكرا .\n\n### MSA translation:\nلقد قضيت وقتاً رائعاً هذا المساء ، شكراً لك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nثقافة قانونيه فايز الكندري اشلونه ؟\n\n### MSA translation:\nثقافة قانونية فايز الكندري كيف حاله؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندي مشكلة. يوم كنت امشي في الشارع، باقوا بوكي. وين مركز الشرطة؟\n\n### MSA translation:\nلدي مشكلة ، حينما كنت أسير في الشارع ، سرقت حافظة نقودي . أين يوجد قسم الشرطة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاهو ليوناردو ده عامل زى كريستيانو كل مرة يجى يسقف\n\n### MSA translation:\nان ليوناردو هذا مثل كرستيانو في كل مره يقوم بالتسقيف<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهو دايما بيعمل شوبينج فى شارع بوند.\n\n### MSA translation:\nإنه يقوم دائماً بالتسوق في شارع " بوند " .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيوم جميل.\n\n### MSA translation:\nيا له من يوم بهيج .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأستاذ فرانك شميدت، مدير مصنعنا، حيكون سعيد انه ياخدك في جولة .\n\n### MSA translation:\nالسيد فرانك شميتد ، مدير مصنعنا ، سيسر لرؤيتك هنا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكتير منيح. هلأ للأسئلة، لو سمحت.\n\n### MSA translation:\nهذا جيد للغاية . والآن الأسئلة ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nحوار انك ترجع في قرار واخده مع نفسك بعد فتره طويل دة صعب\n\n### MSA translation:\nعندما تجد حوار انك ترجع في قرار مع نفسك<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي خمسين غرام من هاللحمة مقطع، إذا بتريد .\n\n### MSA translation:\nأريد خمسين جراماً من شرائح اللحم هذه ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندي ربو .\n\n### MSA translation:\nأعاني من الربو .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تنظف الطاولة، لو سمحت؟\n\n### MSA translation:\nهل من الممكن أن تنظف المنضدة من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاحنا مهتمين بالأزياء.\n\n### MSA translation:\nنحن مهتمون بالأزياء .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعارف انت الى بيبقى عايش فى الدور ؟ عيش انت فى الدور الى فوقيه\n\n### MSA translation:\nهل تعرف الذى يعيش فى الدور عش انت فى الدور الذى فوقه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت اعطيني شوية ادوية باردة .\n\n### MSA translation:\nمن فضلك أعطني دواء للبرد .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبخير، شكرا ليك. وأنت؟\n\n### MSA translation:\nبخير ، شكراً لك ، و أنت ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهى كمان ما كان ببالها؛ فجأة القصة هيك آجيت لحالها\n\n### MSA translation:\nهي أيضا لم يكن في بالها هذا فجأة جاءت القصة وحدها<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوللشرب؟\n\n### MSA translation:\nوللشرب ؟ .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nده ضيق شويه عند البطن .\n\n### MSA translation:\nإنه محكم قليلاً حول المعدة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالنهاردة الساعة سته و نص، لكن العاجي بيكون على خمسه و نص .\n\n### MSA translation:\nستة وثلاثين دقيقة اليوم ، ولكن عادة في الخامسة وثلاثين دقيقة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن قاطعك؟\n\n### MSA translation:\nهل لي أن أقاطعكم ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفي رأي انو البنت توترت كرمال هيك بكيت ولا خص سلام ولا تمام\n\n### MSA translation:\nفي رأيي أن الفتاة توترت لذلك بكت ولا علاقة لسلام أو تمام بالأمر<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبكره صحابي اللي لما نبقي خارجين اقولهم يللا نتصور يفضلوا يقولولي لأ لأ\n\n### MSA translation:\nاكره اصحابي عندما ننوي الخروج اطلب منهم صورة تذكارية الكل يقول لا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفين البحيرة؟\n\n### MSA translation:\nأين البحيرة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأكيد. إنزل السلالم على اليمين هناك هتشوف بعض الإتجاهات. بس إنت إمشي وراهم.\n\n### MSA translation:\nبالتأكيد ، انزل من على الدرج هناك وسوف تجد بعض الإرشادات فاتبعها من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تعملي خصم؟\n\n### MSA translation:\nهل يمكن أن تعطني خصماً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبعتذر، بس رح نتأخر تلاتين ديقة .\n\n### MSA translation:\nآسف ، و لكننا سنتأخر ثلاثين دقيقة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهي فاتورتك. ثلاثمية وسبعة وتسعين دولار.\n\n### MSA translation:\nهاهي فاتورتك . الحساب ثلاثة تسعة وسبعين دولار .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيجماعه بشرونا شصار على المهتقلين ان لم يخرجو سوفا اخرج للاعتصام اليوم\n\n### MSA translation:\nيا جماعة بشرونا ماذا حدث للمعتقلين إن لم يخرجوا سوف أخرج للاعتصام اليوم<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلما بنت تتخانق معاك لمجرد انها خايفة عليك تبقى بتحبك اوى متستغباش\n\n### MSA translation:\nعندما تتشاجر معك لمجرد انها تخاف عليك هذا يعني انها تحبك لا تكن غبي<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالزبده سوولها فول هنا حسابها الثاني مدري شصار فيه\n\n### MSA translation:\nالخلاصة تابعوها هنا لا أدري ماذا حدث لحسابها الثاني<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي تكسي. أنا في ساوث مين و ليبرتي.\n\n### MSA translation:\nأحتاج إلى تاكسي . أنا في ساوث ماين ، وليبرتي .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nابغي سندويج وعصير برتقال.\n\n### MSA translation:\nأريد شطيرة وبعض عصير البرتقال من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشو السعر؟\n\n### MSA translation:\nما هو السعر ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكيمورا ك ي م و ر ا.\n\n### MSA translation:\nإنه كيمورا ك ي م و ر ا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالعجقة كانت مخيفة بمنطقة اتسوجي، صح؟\n\n### MSA translation:\nكان الازدحام المروري فظيعاً في منطقة أتسوجي , أليس كذلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهاد ممزوع.\n\n### MSA translation:\nإنه ممزق .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nآسف، ما نسوي هذي.\n\n### MSA translation:\nأنا آسف . نحن لا نقوم بهذا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nرمية منيحة. بس برا.\n\n### MSA translation:\nركلة موفقة . كادت تدرك الهدف .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفيي انقل عهيداك المقعد؟\n\n### MSA translation:\nهل أستطيع الانتقال إلى هذا المعقد ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهل اقدر استئجر دليل يتكلم باللغة اليابانية؟\n\n### MSA translation:\nهل يمكنني استئجار مرشداً يتحدث اللغة اليابانية ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالبي انقرح مدري اشلون بفارقكم الله يسهل علينا ويوفقنا يا رب\n\n### MSA translation:\nقلبي محطم لا أدري كيف سأفارقكم الله يسهل علينا ويوفقنا يا رب<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنور الرسالة بتاعتي منور.\n\n### MSA translation:\nمصباح الرسائل الخاص بي مضاء .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تجبلي قهوة؟\n\n### MSA translation:\nألا تحضر لي بعض القهوة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالواحد بقى مالوش نفس يعاتب حد او يبرر لحد موقف اللى عايز يفهم حاجة يفهمها\n\n### MSA translation:\nالشخص أصبح لا يرغب بعتاب أحدا أو يبرر لشخصا موقفا من يريد فهم شيئا يفهمه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتعرف الساعة كم يفتح المتحف؟\n\n### MSA translation:\nمتى يفتح المتحف من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتموت بقلب هيك سيارة احلى ما تموت ملقوحة عالطريق وشكرا\n\n### MSA translation:\nأن تموت داخل سيارة كهذه أفضل من أن تموت على قارعة الطريق وشكرا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنسألكم الفاتحة على روح هيث ليدجر يا أخونا في ليلة مفترجة زي دي الله يستركم\n\n### MSA translation:\nنسألكم الفاتحة على روح هيث ليدجر يا أخونا في ليلة مفترجة كهذه الله يستركم<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nايمتى الترين التاني عاوكسفورد؟\n\n### MSA translation:\nمتى القطار التالي إلى أكسفورد ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشنو الأقرب لهني؟\n\n### MSA translation:\nأيهما أقرب من هنا ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي نتلائى.\n\n### MSA translation:\nأود عمل المقابلة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك غرفة فردية حق الليلة؟\n\n### MSA translation:\nهل توجد لديكم غرفة مفردة لهذه الليلة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعطيني علكة، عمول معروف.\n\n### MSA translation:\nأعطني بعض العلكة من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأنا من الناس اللي لو حد قال حته من اي فيلم أو كارتون تلاقيني بكورلك الباقي\n\n### MSA translation:\nانا من الناس الذين اذا ذكرهم احد بمشهد من فيلم تجدني اذكره بباقي الفيلم<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفين الحمامات؟\n\n### MSA translation:\nأين غرف الراحة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاد ايه روعة .\n\n### MSA translation:\nما أروعها .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nحاضر يا أستاذ . ده بييجي أما مع بطاطس محمرة أو رز بيلاف . حضرتك تحب ايه؟\n\n### MSA translation:\nحسناً ، سيدي . فقد أتت بخيارين مقليات فرنسية أو أرز بالتوابل واللحم ، أيهما تحب ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأووه، أنا آسف لأنه أزعجتك.\n\n### MSA translation:\nأوه ، آسف لأني أزعجتك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي انسي اني عايش هيك بعيش اكتر\n\n### MSA translation:\nأريد أن أنسى أنني أعيش هكذا لأعيش أكثر<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nسرقت عمري من أحزاني سرقته لكن ما جاني و لا حد شاف فين مكاني ورا الشبابيك\n\n### MSA translation:\nسرقت عمرى من احزانى سرقته ولكن ما جانى ولا حد رئا اين اكون خلف الشبابيك<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندما يطرق الحب بابك طنش واعمل مش واخد بالك\n\n### MSA translation:\nعندما يطرق الحب بابك لا تاخذ بالك<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانك تسمع اغنيه شمس الحريه وانت بتجري دي كفيله انها تخليك متبطلش جري اصلا\n\n### MSA translation:\nانك تسمع اغنيه شمس الحريه وانت تركض وهذه كفيله بجعلك لن تتوقف عن الركض<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nخدمة الغرف، من فضلك .\n\n### MSA translation:\nتدبير المنزل ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهذا اكاونته الرسمي جذي؟ المستعار اشلون حجي\n\n### MSA translation:\nهذا حسابه الرسمي فكيف يكون حسابه المستعار؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانا مش حاسس اني مرتاح . من فضلك صلح ده بأسرع ما يمكنك .\n\n### MSA translation:\nأشعر بعدم الارتياح . من فضلك أصلحها بأسرع ما يمكن .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتنتحري فينا يا ويلك خلص ما عاد بدي زوجك خليكي هيك\n\n### MSA translation:\nتنتحرين فينا يا ويلك خلاص لم أعد أريد زواجك ابقي هكذا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nخلنا ناكل مع بعض برع.\n\n### MSA translation:\nدعنا نأكل في الخارج سوياً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمنين مفروض اغير القطر عشان اروح سان دييجو؟\n\n### MSA translation:\nأين يجب علىّ أن أغير القطار للذهاب إلى سان دييجو ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهاتبيعك وهي مرتاحة ما هي باعت الجنة بتفاحة عن حواء اتكلم\n\n### MSA translation:\nسوف تتركك وهي في راحة بال هي تركت الجنة بسبب تفاح عن حواء اتكلم<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبروم عاليمين بالشارع .\n\n### MSA translation:\nانعطف يميناً في الشارع .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهو "ت" متل كلمة توم، نعم عندي ياه، يا تارو.\n\n### MSA translation:\nحرف " ت " " كما في توم ، نعم ها هي لدي هنا ، تارو .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nواللي امسوي عملية وعنده مراجعات لتكملة العلاج اشلون يكون وضعه؟\n\n### MSA translation:\nوالذي أجرى عملية ولديه مراجعات لاستكمال العلاج كيف تكون حالته<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو بتخاف على مشاعرها بجد مكنتش وفقت انك تلعب بيها من الأول\n\n### MSA translation:\nلا تلعب بمشاعر اي فتاة ان كنت تحبها فعلا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفيه حد تاني اخده بالغلط .\n\n### MSA translation:\nيبدوا أن شخصاً ما قد أخذها عن طريق الخطأ .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nليلنا يا ليلنا مره هتحللنا تميل على ميلنا فى دايرة الرحله منير\n\n### MSA translation:\nليلنا يا ليلنا ذات مرة ستصبح حلوا وتميل على ميلنا في داية الرحلة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعذريني اذا غلطان، بس مش انت ريبيكا اندرسوزن؟\n\n### MSA translation:\nاعذريني لو كنت مخطئا , لكن ألستِ ريبيكا أندرسون ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاحساس انك عايزه تضرب حد لحد متتعب من كتر الضرب وبعدين تترمي فحضنوا\n\n### MSA translation:\nإحساس أنكي ترغبين في ضرب أحدهم حتى تصابين بالتعب من كثرة الضرب ثم تنامين بين أحضانه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاي خلنا من الجثة السيارة الي بقتها شصار عليها ؟\n\n### MSA translation:\nدعنا من الجثة السيارة التي سرقتها ماذا حدث لها؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلازم أعمل اتصال. رايح على بوسطن.\n\n### MSA translation:\nكان يجب تدبير وسيلة مواصلات . ذاهبة إلى بوسطن .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشو بدك تعرف عنه واحد قاعد بفرق بين الناس ع أردني وفلسطيني\n\n### MSA translation:\nماذا تريد أن تعرف عنه؟ إنه شخص جالس يفرق بين الناس إلى أردني وفلسطيني<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهلئ دقيت لأستاذ سميث بالغرفة تنين صفر واحد، بس ما حدا رد. بتشوف إذا لساتو بقيان هون؟\n\n### MSA translation:\nلقد اتصلت بالسيد سميث في غرفة رقم اثنان صفر واحد منذ لحظات ، لكن لم يرد أحد . هل لك أن ترى هل لا يزال يقيم هنا ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو بتحبها بجد أول ما هتلاقيها بتدمع هتحن حتي لو هي الغلطانة\n\n### MSA translation:\nإذا كنت تحبها ستشعر بالحنين لها حتى إذا كانت هي المخطئة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنص اللى قالوا مفيش داروا حاجات ياما لو حكيوا ميكفيش من بكرة لقيامة\n\n### MSA translation:\nنصف الذين قالوا لا يوجد .. داروا أشياء يا أماه إذا حكوا لا يكفى .. من غذا الى القيامة ..<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبتحب تشرب إشي؟\n\n### MSA translation:\nهل تبغي شراباً ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفى ناس لازم يتكتب ع وشها الكلام مع هذا الشخص مضر بالصحه ويسبب الوفاه\n\n### MSA translation:\nهناك اناس مكتوب على وجهها .. التحدث مع هذا الشخص مضر بالصحه ويسبب الوفاه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالفاشلون قسمان قسم فكر ولم يفعل وقسم فعل ولم يفكر حقيقه\n\n### MSA translation:\nالفاشلون قسمان قسم فكر ولم يفعل وقسم فعل ولم يفكر حقيقة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأنا هجيب واحد حالا.\n\n### MSA translation:\nسوف أحضر واحدة في الحال .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاكيد، ما تهتم . انتبهت لكل شي .\n\n### MSA translation:\nبالتأكيد لا تقلق ، لقد توليت كل شيء .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nطيب ليش؟\n\n### MSA translation:\nلماذا إذاً ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي ضو، إذا بتريد .\n\n### MSA translation:\nأريد إضاءة متواترة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي اخدا .\n\n### MSA translation:\nأود أن آخذه .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nايه ده كل ما بنكبر بنتغابي ليه ؟\n\n### MSA translation:\nما هذا لماذا نتقدم في العمر ونصبح اغباء ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالعاشقون الناجحون الفاشلون مؤلم جدا\n\n### MSA translation:\nالعاشقون الناجحون الفاشلون مؤلم جدا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبشكر الناس ال زاعت الاوسكار ع التايم لاين من غيرهم كنت اتحرمت من فرجته\n\n### MSA translation:\nبشكر الناس ال زاعت الاوسكار ع التايم لاين من غيرهم كنت اتحرمت من فرجته<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nابغى اجلس بهالغرفة ليلة زيادة.\n\n### MSA translation:\nأود الإقامة بهذه الغرفة ليلة واحدة أخرى .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكاسين فراوله مجمده بالكريمة و البيض و السكر بارفيه .\n\n### MSA translation:\nاثنان من حلوى الفراولة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالمجد لكل شخص بيسمع ال بيعجبه ايا كان الكلام ال بيتقال علي ال بيسمعه\n\n### MSA translation:\nالمجد لكل شخص يسمع الذي يعجبه أيا كا نالكلام الذي يقال على ما يسمعه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلا ما بيسوا الكبتاغون شو بدك بهلخبريات\n\n### MSA translation:\nلا يستحق الكبتاغون ماذا تريد بمثل هذه الأخبار؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنفسك في حلا؟\n\n### MSA translation:\nهل تريد بالحلويات ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفي تخفيض للطلاب؟\n\n### MSA translation:\nهل ثمة تخفيضات للطلبة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين الحمامات؟\n\n### MSA translation:\nأين غرف الراحة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانتا عارف انا لو كنت عملت الى انتا بتعملو دا كان زمانى خسرتك من زماان\n\n### MSA translation:\nهل تعلم أني لو فعلت ما تفعله أنت كان من الفترض ان اخسرك منذ مدة طويلة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفينا نروح ع تيكي بوينت بكرا؟\n\n### MSA translation:\nهل يمكن أن نذهب إلى نقطة تكي غداً ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعلمونى اعشق صحابى وانسى وياهم عذابى هما فين الصحاب دول ياسطى ؟\n\n### MSA translation:\nعلموني ان اعشق اصدقائي وانسي معهم عذابي اين هما هولاء الاصدقاء<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت إديلى عنوانك عشان لو حصل حاجة طارئة.\n\n### MSA translation:\nمن فضلك أخبرني بعنوان المراسلة عليك في حالة الطوارئ .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكتير كويس. هلئ عالأسئلة، إذا سمحت.\n\n### MSA translation:\nهذا جيد للغاية . والآن الأسئلة ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاشكرك . من فضلك أدفع عن الكاشير هناك . اشكرك تاني .\n\n### MSA translation:\nشكراً . من فضلك ادفع عند المحصل هناك . شكراً مرة أخرى .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nآسف. عطيته شخص ثاني قاعد في نفس الغرفة.\n\n### MSA translation:\nأنا آسف . لقد أعطيتها لشخص آخر يقيم في نفس الغرفة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تورجيني واحد أكبر بشوي؟\n\n### MSA translation:\nهل يمكنك أن تريني حجماً أكبر بقليل ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nياريتك كنتي زباله عشان اشوفك في كل مكان مصري معفن بيحب حبيبته\n\n### MSA translation:\nيا ليتكى كنتى قمامه من اجل ان انظر لك فى كل مكان 33 مصرى عفن يحب محبوبته .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفي حدا انصاب .\n\n### MSA translation:\nلقد أصيب شخص .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلازم نروح عمنصة رقم واحد لنركب خط شيو.\n\n### MSA translation:\nيجب أن نذهب إلى الرصيف رقم واحد للركوب على خط شيو .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيشغلون موسيقى الجاز في هالمكان؟\n\n### MSA translation:\nهل يعزفون موسيقي الجاز في هذا المكان ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبقعد في الهوليدي اين داونتاون لي خمسة مايو.\n\n### MSA translation:\nإنني أنوي قضاء الإجازة في وسط المدينة حتى الخامس من شهر مايو .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتم ساكت ولا بثور.\n\n### MSA translation:\nالتزم السكون وإلا أطلقت النار .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكيف كان هالمطعم؟\n\n### MSA translation:\nكيف وجدت هذا المطعم ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nطاولة لغير المدخنين، لو سمحت.\n\n### MSA translation:\nمائة غير المدخنين من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالهدف من تويتر ان كل واحد يطلع المهرتل الصغير الى موجود جواه\n\n### MSA translation:\nالهدف نت التغريد ان يخرج كل منا مابداخله<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكم عدد مقاعد البرندة؟\n\n### MSA translation:\nما تكلفة المقاعد الخاصة بالشرفة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nو اللى عنده ميول انتحارية بس مع اللى بيحبه يعمل ايه يموتوا سوا بقى\n\n### MSA translation:\nأي شخص عنده ميول إنتحارية مع الشخص الذي يحبة فقط ماذا يفعل يقوموا بالإنتحار سويا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبيتك كبير. كم غرفة؟\n\n### MSA translation:\nمنزلك كبير . كم عدد الغرف ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيالا الحمدلله في وجود الجمهور هنا هنخلص الماتش سهل إن شاء الله\n\n### MSA translation:\nالحمد لله فى وجود هذا الجمهور سوف ننهى الماتش بسهوله ان شاء الله<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشلون استخدم هالمضخة؟\n\n### MSA translation:\nكيف أستخدم تلك المضخة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالجيش امبارح كان بيغنى مش ناسيين التحرير للشرطة\n\n### MSA translation:\nالجيش امس كان يغني لا ننسي التحرير للشرطة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعفكره مسلي اوك و ما ترد عالبحكي غير هيك\n\n### MSA translation:\nللمعلومية مسلي حقا ولا تصدق من يقول شيئا آخر<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبداية زهايمر الكل يصير فيه هيك وانا اولهم\n\n### MSA translation:\nبداية الزهايمر الكل يصيبه نفس الشيء وأنا أولهم<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلازم اروح المحطة الحين.\n\n### MSA translation:\nلابد أن أذهب إلى المحطة الآن .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهي ليه الناس بتعتبر كلب شتيمه؟ مع أن الكلاب احسن و اوفي من البنأدمين\n\n### MSA translation:\nلماذا الأشخاص بتعتبر كلب سب؟ مع أن الكلاب أفضل وأوفى من البشر<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالناس اللي يغلطون ثم يزعلون وش تبون من الدنيا ؟\n\n### MSA translation:\nأتعجب من أناس يخطئون ثم يغضبون<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nسلة النصر محتاجة دعمنا وش تبون بكورة القدم مملة ومافيها حماس\n\n### MSA translation:\nسلة النصر تحتاج إلى دعمنا ماذا تريدون بكرة القدم؟ إنها مملة ولا حماس فيها<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت أعطيني تقرير للحادث.\n\n### MSA translation:\nمن فضلك أعطني تقريراً عن الحادث .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبغيت اكل يهال.\n\n### MSA translation:\nأحب بعض طعام الأطفال .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهل يمكن أن نبدأ اللعب لما يخلص؟\n\n### MSA translation:\nهل يمكن أن نبدأ اللعب عندما ينتهون ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهو اية دة لازم الواحد يشتم عشان يشتهر ؟ مش رواشة على فكرة\n\n### MSA translation:\nماذا يحدث يجب ان اوبخ احدا هذه شىء سيء<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nسكر؟\n\n### MSA translation:\nسكر ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاحسن انو نلاقي مكتب خطوط يونايتد هلق.\n\n### MSA translation:\nمن الأفضل أن نعثر على العداد الأصلي لشركة يوتيتد إيرلاينز الآن .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبناسبني منيح.\n\n### MSA translation:\nتناسبني تماما .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمن وضلك وريني حاجة ارخص .\n\n### MSA translation:\nمن فضلك أرني واحدة أرخص .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمتهيألي ان ده كرسيا .\n\n### MSA translation:\nأعتقد أن هذا مقعدي .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهل في باص من المطار؟\n\n### MSA translation:\nهل لديك أتوبيس من المطار ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأديش بتريد حق عدسة نيكون عين السمكة؟\n\n### MSA translation:\nما الثمن الذي تطلبه في عدسة عين السمكة من نوع نيكون ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالكسل ممكن يمنعنا عن اى حاجه الا الاكل و النوم\n\n### MSA translation:\nالكسل ممكن يمنعنا عن اى حاجه الا الاكل و النوم<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nطعمو غريب.\n\n### MSA translation:\nأنه ذو مذاق غريب .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nماحد ينصحني خليني خربان هيك احلى\n\n### MSA translation:\nلا أريد النصيحة من أحد دعوني كما أنا أفضل<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمشاهير فاشلون النسخہ العربية اعجبني\n\n### MSA translation:\nالمشاهير الفاشلون؛ النسخة العربية أعجبتني<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nازيك، تاناكا . انا مبسوط اني الاقيك هنا . انت نازل فين؟\n\n### MSA translation:\nمرحباً ، تاناكا . أنا مسرور لوجودك هنا . أين تقيم ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعاوز أجيب عربية جدبدة.\n\n### MSA translation:\nأتمنى أن أخذ سيارة جديدة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأعرف أنها وأنها وأنها لكني مش فاضي ولذلك بعتها\n\n### MSA translation:\nأعرف أنها وأنها وأنها لكنى مشغول لذلك بعتها<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهو قريب خرج ينمشالو؟\n\n### MSA translation:\nهل هو قريب لنصل إليه سيراً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبقدر استأجر عدة غطس؟\n\n### MSA translation:\nهل أستطيع تأجير أداة للتنفس أثناء السباحة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأنا مش عاوز أصرف أكتر من عشرين دولار.\n\n### MSA translation:\nلا أريد إنفاق أكثر من عشرين دولاراً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو انا مكانك، كنت حأحاول .\n\n### MSA translation:\nلو كنت مكانك لجربت ذلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبالله حطه في كيس غسيل وخليه هناك.\n\n### MSA translation:\nمن فضلك ضعه في كيس الغسيل و اتركه هناك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكل قراراتهم تالي الليل ودي افهم اشلون\n\n### MSA translation:\nكل قراراتهم آخر الليل ودي أفهم كيف<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأخر 1 من البطارية أغلى عندى من ناس كتير اه والله\n\n### MSA translation:\nالعشرة في المائة الاخيرة من شحن البطارية عندي اهم من اناس كثيرون<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن توريني هذي، لو سمحت؟\n\n### MSA translation:\nهل يمكنك أن تريني هذا من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيصير تعطيني تخفيض؟\n\n### MSA translation:\nهل يمكنك أن تقدم لي خصماً ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاي. احس اني تعبان من يومين.\n\n### MSA translation:\nنعم . لم أشعر بأنني لست على ما يرام منذ حوالي يومين .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيمكن ييجى الأولانى\n\n### MSA translation:\nفكر مرتين قبل ان تتحدث فقد يحضرك ردا اكثر ملائمة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nما ياكلون بيض ني في امريكا.\n\n### MSA translation:\nإنهم لا يأكلون البيض نيئاً في الولايات المتحدة الأمريكية .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك شي رحلات عالبانثيون؟\n\n### MSA translation:\nهل لديكم أي جولات للبانتيون ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفين اقرب محل اكل صحى؟\n\n### MSA translation:\nأين أقرب متجر أغذية صحية ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمعظم النصايح اللى بننصح بيها غيرنا احنا مبنعملهاش\n\n### MSA translation:\nمعظم النصائح التي ننصح بها غيرنا نحن لا نفعلها<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالممثل واجد عجيب.\n\n### MSA translation:\nكان الممثل رائعا بالفعل .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك خريطة مدينة لهالمنطقة؟\n\n### MSA translation:\nهل لديك خريطة لهذه المنطقة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنحن منستعمل العود وقت مناكل.\n\n### MSA translation:\nنستخدم الأعواد عندما نأكل .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلحد امتى هفضل اجوع كل يوم فى الوقت دة في مصلحة مين دا ها\n\n### MSA translation:\nالى متى سأظل أشعر بالجوع يوميا في مثل هذا الوقت لمصحلة من هذا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلا لا اشلون جذي لا تقول يبا لاعبيين مع برشا\n\n### MSA translation:\nلا لا كيف ذلك لا تقل يا أبي اللاعبون مع برشلونة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانسى الناس وفكر فى ربنا الناس هتنساك لكن ربنا دايما فكرك\n\n### MSA translation:\nأنسى الأشخاص وفكر فى الله الأشخاص سوف تنساك ولكن الله يظل يتذكرك دائما<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك شوربة بصل؟\n\n### MSA translation:\nهل عندكم أية شربة بصل ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nرحت عالبحيرات الكبرى لأول مرة.\n\n### MSA translation:\nلقد قمت بزيارة البحيرات الكبرى لأول مرة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت استعجل، اذا ممكن .\n\n### MSA translation:\nقم بدفعها من فضلك , إن كان ذلك ممكنا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأيه طبق المطعم المخصوص؟\n\n### MSA translation:\nما هو الصنف المميز لهذا المطعم ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمن زمان عنج اشلونج بوسه على الكسكوس\n\n### MSA translation:\nمن زمن طويل لم أراك كيف حالك؟ قبلة على جبهتك<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nحق النقابه بمطالبة اي نقص او اي بدل من حقهم اشلون مو اختصاصهم\n\n### MSA translation:\nمن حق النقابة المطالبة بأي نقص أو أي بدل كيف هذا ليس من اختصاصهم؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكل أربعاء هنوزع ا جزاء علشان الخميس نبدء الختمه ريتويت واعملوا فولو\n\n### MSA translation:\nكل أربعاء نفرق ا جزاء لان الخميس نبدء الختمه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكم تكلفة المرشد لكل يوم؟\n\n### MSA translation:\nكم يتقاضى المرشد في اليوم ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبهذا المقاس، لو سمحت.\n\n### MSA translation:\nبهذا المقاس من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأشكرك، كويس، خليني أشوف. في الحقيقة، مش ده اللي عايزه.\n\n### MSA translation:\nشكرا . حسنا , دعني أرى . في الواقع , ليست هي التي أريدها .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمبين إنه ممتع. كم بكلف؟\n\n### MSA translation:\nهذا يبدو رائعاً . ما الثمن ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبتفترح كتاب منيح لولد عمرو خمستاعشر سنة؟\n\n### MSA translation:\nهلا أرشدتني إلى كتاب جيد لطفل يبلغ من العمر خمسة عشر عاما ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشو بدك اقول انا هيك بحب لي بيحبني وما بوطي رأسي لحدا خاني\n\n### MSA translation:\nماذا تريدني أن أقول؟ أنا هكذا أحب من يحبني ولا أخفض رأسي لأحد خانني<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين اقدر آخذ التذكرة؟\n\n### MSA translation:\nمن أين يمكنني الحصول على التذكرة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانا هغادر من مطار ايه؟\n\n### MSA translation:\nمن أي المطارات سأغادر ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nو هيجي اليوم اللي هتقولو فيه مات امتى دة كان بيكلمنى امبارح ؟\n\n### MSA translation:\nوسوف يأتي اليوم الذ تقولوا فيه .. مات متى هذا كان يحادثني امس ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمدري اذا حطيت ملابس كفأية لرحلة أبو تلاتة أسابيع.\n\n### MSA translation:\nأنا غير متأكد إذا كنت قد حزمت ملابس كافية لرحلة مدتها ثلاثة أيام .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nخدني عند الشرطة.\n\n### MSA translation:\nخذني إلى الشرطة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تطرش لي احد هني الحين؟\n\n### MSA translation:\nهل لك أن ترسل أحداً ما إلى هنا فوراً ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nسعات بنحس بحاجات واما نيجي نقول يروح كل الكلام منا وسكوتنا يطول\n\n### MSA translation:\nاحيانا نشعر باشياء وعندما يحين الوقت لقولها يذهب كل الكلام وصمتنا يطول<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكم السعر على الورقة الوحدة؟\n\n### MSA translation:\nكم تكلف الملاءة الواحدة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nآسف، راجعت مع خدمة الغرف ومكتب المفقودات. ماعندهم.\n\n### MSA translation:\nآسف ، لقد تحققت من إدارة الخدمة وإدارة المفقودات ولم أجدها عندهم .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلا، انت توقعت صح. تطلقت قبل ست شهور تقريباً.\n\n### MSA translation:\nلا ، لقد خمنت صواباً . لقد طلقت من حوالي ستة أشهر .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبص على التعليمات اللي على علبة الأكل المفرغة من الهوا.\n\n### MSA translation:\nانظر التعليمات على علبة الطعام الفارغة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبقدر اخذ رقم اي بي سي اند كومباني بشيكاغو، لو سمحت .\n\n### MSA translation:\nهل يمكنني أن أحصل على رقم تليفون إيه بي سي والشركة في شيكاغو من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالبرج ده كبير قد إيه؟\n\n### MSA translation:\nما حجم هذا البرج ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاذا في سبب يخليك تنبسط ما بصير تنبسط مشان في ناس مش مبسوطين\n\n### MSA translation:\nاذا فى سبب يجعلك تنبسط من غير المعقول تنبسط لاجل ناس غير مبسوطين<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأديش اجرة التاكسي من هاد الأوتيل عالمحطة؟\n\n### MSA translation:\nكم أجرة التاكسي من هذا الفندق إلى المحطة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nواجد دفا. ممكن تعدل الكنديشن؟\n\n### MSA translation:\nالجو دافئ جدا . أيمكنك ضبط التكييف من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاظن ان هذي كل شي اليوم، اخواني.\n\n### MSA translation:\nاعتقد أننا قد أنهينا عملنا اليوم ، يا سادة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nسارو حتى كلج حلا وانتي وهي كيك وعسل لكن مو بصحون\n\n### MSA translation:\nسارو حلا وأنت وهي كيك وعسل ولكن ليس في صحون<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمفيش أسوأ من اننا نخاف من العيب أكتر من خوفنا من الحرام حقيقة\n\n### MSA translation:\nليس هناك أسوء من خوفنا من العيب أكثر من الحرام حقيقه<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانتم تدعمون الحوثيين والاخوان بالخليج اقول اشلون عمتك موزه بس\n\n### MSA translation:\nأنتم تدعمون الحوثيين والإخوان في الخليج أقول كيف حال عمتك موزة فقط؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبتقدر تحكيه بكلمات ثانية؟\n\n### MSA translation:\nهل يمكن أن تقول لي ذلك بعبارة أخرى ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nرح أكون هون على التمنية الا ربع.\n\n### MSA translation:\nسأكون هنا الساعة الثامنة إلى الربع .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممنوع السباحة هون؟\n\n### MSA translation:\nألا يسمح بالسباحة هنا ؟<eos>',
# ...
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nزعلان نرضيك ونزيدك رضا وازود اشلون تراضيني\n\n### MSA translation:\nحزين نراضيك ونزيدك رضا ولكن كيف تراضيني؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاوه، حلو. عجبني صوتهم. وانت، بوب؟\n\n### MSA translation:\nأوه ، هذا بديع . أحب صوتهم . ماذا عنك يا بوب ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيلا هيك هيك ما في لا حج ولا عمرة\n\n### MSA translation:\nهكذا هكذا لا يوجد حج ولا عمرة<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتحي ايه عالعشا، لحم أو سمك؟\n\n### MSA translation:\nأيهما تفضل في العشاء ، لحم بقري أم سمك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو عملت سندوتش واحد مش بشبع انما لو عملت سندوتشين بشبع من اول واحد\n\n### MSA translation:\nاذا اعددت سندوتش واحد لا يشبع انا اذا اعددت سندوتش يشبع من اول واحد<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالاسمي قورو موتوياما. والرقم صفر تلاتة تلاتة اتنين ستة واحد اتنين أربعة تسعة خمسة.\n\n### MSA translation:\nالاسم هو جورو موتوياما . والرقم هو صفر ثلاثة ثلاثة اثنان ستة واحد اثنان أربعة تسعة خمسة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nهذي استلام الامتعة مال خطوط يونايتد الجوية؟\n\n### MSA translation:\nهل هذه هي دعوى الأمتعة الخاصة بشركة يوناتيد آير لاينز ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشنطة بنى صغيرة. جلد.\n\n### MSA translation:\nحقيبة صغيرة بنية اللون . إنها مصنوعة من الجلد .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nحر يشيله حر ما هي غريبه شوف الحرار اشلون تعرف بعضها\n\n### MSA translation:\nحر يحمل حرا ليست غريبة انظر كيف تعرف الصقور بعضها البعض<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nازاى أوصل للمكان ده؟\n\n### MSA translation:\nكيف أصل إلى ذلك المكان ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندي ربو .\n\n### MSA translation:\nأعاني من الربو .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nما حجم الي تبغاه؟\n\n### MSA translation:\nأي مقاس تريد ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبروب أحلى طلعه مع رجلي بعد اشلون تبوني امشي بدون رجولي ؟\n\n### MSA translation:\nبروب أحلى طلعة مع زوجي فكيف تريدونني أن أخرج بدون زوجي؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندي بعض الأشياء للغسيل.\n\n### MSA translation:\nلدي بعض الملابس للمغسلة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت عط هذا الشراب لولدك، وحدة واحدة، بعد كل وجبة.\n\n### MSA translation:\nمن فضلك أعط طفلك هذا الدواء الشراب , جرعة واحدة بعد كل وجبة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nستار وورز حقق أعظم نجاح فى ألف تسعماية أربعة وتمانين.\n\n### MSA translation:\nكان فيلم " حرب الكواكب " أكثر الأعمال شعبية عام ألف وتسعمائة وأربعة وثمانون .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن لو سمحت تخلى بالك من شنطة السفر بتاعتى؟\n\n### MSA translation:\nهلا راقبت حقيبتي من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nقلت أنك بتغادر إلى طوكيو غدا؟\n\n### MSA translation:\nهل قلت إنك ستغادر إلى طوكيو غدا ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين التواليت؟\n\n### MSA translation:\nأين دورة المياه ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تغير البوجيهات، لو سمحت؟\n\n### MSA translation:\nهلا بدلت شموع الاحتراق هذه من فضلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nإيمت لازم أكون بالمحطة؟\n\n### MSA translation:\nمتى يتعين علي أن أكون في المحطة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nصديقي زلق وطاح في الحمام.\n\n### MSA translation:\nلقد انزلقت قدما صديقي وسقط في الحمام .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين بقدر لاقي باص حتى روح على بوسطن؟\n\n### MSA translation:\nأين يمكن أن أخذ حافلة للذهاب إلى بوسطن ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاكيد، في هالحالة، الخطوط الجوية بتقدم تعويض.\n\n### MSA translation:\nطبعاً ، في هذه الحال ، ستقدم شركة الطيران تعويضاً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nكل مصاريف المواصلات محسوبة؟\n\n### MSA translation:\nهل تم إدراج جميع تكاليف النقل ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين الحلوه اليوم شصار معاجج\n\n### MSA translation:\nأين أنت يا جميلة اليوم ماذا حدث لك<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتاني واحد عاليمين .\n\n### MSA translation:\nإنها التالية من على اليمن .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين في مكان حلو لرحلة ليوم-واحد؟\n\n### MSA translation:\nأين يوجد مكان لطيف لقضاء نزهة ليوم واحد ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تضيقلي الخصر تلاتة سانتي؟\n\n### MSA translation:\nهل لك بأن تضيق منطقة الوسط سنتيمترات ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت شغل العداد.\n\n### MSA translation:\nمن فضلك ابدأ العداد .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك كوكتيلات مميزين؟\n\n### MSA translation:\nهل لديكم أي أنواع خاصة من الكوكتيل ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nما تظن اني بحتاج دليل؟\n\n### MSA translation:\nألا تعتقد أنني سأكون في حاجة إلى دليل ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانا سمعتها اكتر من مرة حلوة اوي\n\n### MSA translation:\nأنا سمعتها أكثر من مرة جميلة جدا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفينا نشوف قائمة؟\n\n### MSA translation:\nهل لنا أن نطلع على القائمة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأسف، انا حأخد بالي من الكلب.\n\n### MSA translation:\nعفوا , أنا سأعتني بالكلب .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تشرحلي كيف بعمل هيك؟\n\n### MSA translation:\nهل يمكنك توضيح كيفية عمل ذلك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nوين الارضي؟\n\n### MSA translation:\nأين مترو الأنفاق ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nابغى كوب من القهوة البيضاء، لو سمحت.\n\n### MSA translation:\nمن فضلك ، أريد فنجاناً من القهوة البيضاء .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفى ناس ساعات بتمثل انها بتحبك عشان يضيعوا وقت فراغهم مش اكتر\n\n### MSA translation:\nبعض الاشخاص تدعي حبك لتمضي بعض الوقت فقط<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعندك بطاريات لهذي الكاميرا؟\n\n### MSA translation:\nهل لديك أحجار بطارية لهذه الكاميرا ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمتى يوصل ميلانو؟\n\n### MSA translation:\nمتى تصل إلى ميلانو ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nيمكن أن ياخذ الصحون؟\n\n### MSA translation:\nهل يمكن أن آخذ الأطباق الخاصة بك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعايز ده، لو سمحت.\n\n### MSA translation:\nأريد هذه ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت. عندك مانع تتبادل معي بالمقعد؟\n\n### MSA translation:\nمعذرة . هل تمانع في أن تبادل المقاعد معي ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nحاسب، السقف نازل.\n\n### MSA translation:\nكن حذراً ، السقف منخفض .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشلونك يا يوسف شفت شصار فيني 27 حساب من البارحة لليوم\n\n### MSA translation:\nما أخبارك يا يوسف هل رأيت ماذا حدث لحسابي من البارحة إلى اليوم؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدك افحص تحت الطبون؟\n\n### MSA translation:\nهل تريد أن افحص موتور السيارة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعايز أأجر لوح تزلج شراعي .\n\n### MSA translation:\nأود استئجار لوح شراعي .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاحنا ما طلبناش ده .\n\n### MSA translation:\nلم نطلب هذا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nإنت ف عربية كام؟\n\n### MSA translation:\nما الحافلة التي كنت على متنها ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانا فعلا بحبه .\n\n### MSA translation:\nأحبه فعلاً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nٰ مادري غرقت اشلون وانا على البر وش راح مني وش بقى من أماني ٰ\n\n### MSA translation:\nلا أعلم كيف غرقت وأنا على اليابسة ماذا فقدت وما الذي تبقى من أملي<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشو بدك بالثلج مضر للصحة خلينا بالنبيذ\n\n### MSA translation:\nماذا تريد بالثلج؟ مضر للصحة لنبقى على النبيذ<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن تكتب عنوان الاتصال بتاعك هنا؟\n\n### MSA translation:\nهل يمكنك كتابة عنوانك في هذا المكان ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلالا مانتحمل بدون ثلج اجل اشلون لانزل\n\n### MSA translation:\nلا لا نتحمل بدون ثلج إذا كيف ننزل؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانا متدرب.\n\n### MSA translation:\nأنا متدرب .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nليه ما ننتظر الباص تحت المظلة؟\n\n### MSA translation:\nلماذا لا ننتظر الحافلة تحت التندة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعاوز ادفع حسابي .\n\n### MSA translation:\nأود أن أدفع فاتورتي .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nدى كابريو قاعد جمب ساندرا بولوك اتنين اوسكار هنا والنبي\n\n### MSA translation:\nدى كاريو يجلس بجانب ساندرا بولوك لو سمحت اثنان اوسكار هنا<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nتويتر يعني يتفتح من الموبايل لكن اللي بيفتحوه من اللاب دوول فاتهم كتير\n\n### MSA translation:\nتويتر يعني ان نقوم بفتحه من الهاتف النقال لكن من يقوموا بفتحه من الكمبيوتر المحمول ينقصهم كثير<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن استلف سيلوتيب؟\n\n### MSA translation:\nهل لي أن اقترض بعض الأشرطة اللاصقة ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفيه حاجة غلط مع لمبة قلاش الكاميرا .\n\n### MSA translation:\nهناك خطأ ما في لمبة الفلاش .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبغيت بودرة وجه، لو سمحت.\n\n### MSA translation:\nأريد بعض من مسحوق الوجه ، من فضلك .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nاي، بس هيك كتير وأنا أصلاً شبعان.\n\n### MSA translation:\nأجل ، ولكن هذا كثير جدا ، ولقد شبعت بالفعل .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلازم محلب يجيب مصطفى بقري في الوزارة ده رأيي كهشام اللبان يعني\n\n### MSA translation:\nيجب أن يقوم محلب بضم مصفى بقري في الوزارة . ده رأيي كهشام اللبان<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nنومتك بالقبر ماهي حلوه آه يا مسموم يبني اشلون بلوه\n\n### MSA translation:\nنومك في القبر ليس جميلا آه يا مسموم ابني كيف هو البلاء<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nإي.\n\n### MSA translation:\nبلى .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nممكن اخلي هالبطاقة عندي؟\n\n### MSA translation:\nهل يمكنني الاحتفاظ ببطاقة المفتاح هذه ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمتزلج جيد.\n\n### MSA translation:\nيا له من راكب ماهر للأمواج .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nخير لي انا وش تبون انتو ؟؟\n\n### MSA translation:\nخير لي أنا؟ ماذا تريدون أنتم؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nما فيه صابون في غرفتي.\n\n### MSA translation:\nليس هناك صابون في حجرتي .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nأحسنلك تدخل مشفانا.\n\n### MSA translation:\nمن الأفضل لك أن تدخل مستشفانا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nعايز شوية مسحوق غسيل.\n\n### MSA translation:\nأريد بعضاً من مسحوق الغسيل .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nشكرا. بيعمل ايه؟\n\n### MSA translation:\nشكرا . ما نوع الوظائف التي تقوم بها ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nالسستم مايبطل اشلون بنسجل ؟؟\n\n### MSA translation:\nالنظام لا يقبل كيف نقوم بالتسجيل<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nودي ازور متحف ميتروبوليتان للفنون ومركز لينكولين، بعد.\n\n### MSA translation:\nأحب زيارة متحف متروبوليتان للفنون ومركز لنكولن , أيضا .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nانت تعيش بروحك؟\n\n### MSA translation:\nهل تعيش بمفردك ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nفي شي بب هون؟\n\n### MSA translation:\nهل توجد حانة قريبة من هنا ؟<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمتهيألي ده ضيق سنة صغيرة.\n\n### MSA translation:\nأظن أنها بالغة الضيق على حد ما .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nلو سمحت اعطي هاد الشراب لطفلك، مقدار واحد بعد كل وجبة .\n\n### MSA translation:\nمن فضلك أعط طفلك هذا الدواء الشراب , جرعة واحدة بعد كل وجبة .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبمشي بكرة من الصبح.\n\n### MSA translation:\nسأغادر في الصباح الباكر غداً .<eos>',
#  'Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nمن متى كانت في المملكة المتحدة؟\n\n### MSA translation:\nكم المدة التي قضتها هي حتى الآن في المملكة المتحدة ؟<eos>',
#  ...]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 16,
        gradient_accumulation_steps = 2, # Simulates a batch size of 2 x 4 = 8 by accumulating gradients before updating weights.
        warmup_steps = 5,
        num_train_epochs=1,
        learning_rate = 5e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(), # uses bf16 (a floating-point formats) for effiency if supported
        logging_steps = 1, # number of training steps that should pass before the training process logs information like loss, metrics, and other relevant data to the console
        optim = "adamw_8bit", # An 8-bit version of AdamW to reduce memory usage.
        weight_decay = 0.01, # Think if I need to change this - Helps prevent overfitting.
        lr_scheduler_type = "linear", # Reduces learning rate gradually.
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Converting train dataset to ChatML (num_proc=2):   0%|          | 0/62775 [00:00<?, ? examples/s]
# Applying chat template to train dataset (num_proc=2):   0%|          | 0/62775 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=2):   0%|          | 0/62775 [00:00<?, ? examples/s]
# Truncating train dataset (num_proc=2):   0%|          | 0/62775 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.557 GB.
# 15.209 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 62,775 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 16 | Gradient Accumulation steps = 2
# \        /    Total batch size = 32 | Total steps = 1,962
#  "-____-"     Number of trainable parameters = 114,180,096
# AUTOTUNE bmm(512x89x128, 512x128x89)
#   triton_bmm_14 0.0686 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_3 0.0727 ms 94.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_10 0.0737 ms 93.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_5 0.0758 ms 90.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   bmm 0.0768 ms 89.3%
#   triton_bmm_13 0.0768 ms 89.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_6 0.0829 ms 82.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_15 0.0829 ms 82.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   triton_bmm_18 0.0840 ms 81.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_0 0.0870 ms 78.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
# SingleProcess AUTOTUNE benchmarking takes 2.2712 seconds and 0.0100 seconds precompiling
# AUTOTUNE bmm(512x89x89, 512x89x128)
#   triton_bmm_33 0.0563 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_29 0.0625 ms 90.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_24 0.0635 ms 88.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_32 0.0635 ms 88.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   bmm 0.0676 ms 83.3%
#   triton_bmm_25 0.0676 ms 83.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_34 0.0686 ms 82.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   triton_bmm_22 0.0707 ms 79.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_19 0.0717 ms 78.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_28 0.0748 ms 75.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 2.2517 seconds and 0.0022 seconds precompiling
# AUTOTUNE bmm(512x89x89, 512x89x128)
#   bmm 0.0553 ms 100.0%
#   triton_bmm_81 0.0584 ms 94.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_78 0.0625 ms 88.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_76 0.0635 ms 87.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_79 0.0748 ms 74.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_82 0.0860 ms 64.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_85 0.0870 ms 63.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_89 0.0881 ms 62.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_90 0.1055 ms 52.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_86 0.1075 ms 51.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.2897 seconds and 0.0019 seconds precompiling
# AUTOTUNE bmm(512x89x128, 512x128x89)
#   triton_bmm_95 0.0614 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_105 0.0614 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_104 0.0625 ms 98.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   bmm 0.0645 ms 95.2%
#   triton_bmm_108 0.0645 ms 95.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_100 0.0655 ms 93.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_101 0.0655 ms 93.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_109 0.0676 ms 90.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_110 0.0707 ms 87.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   triton_bmm_97 0.0727 ms 84.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.2688 seconds and 0.0023 seconds precompiling
# AUTOTUNE bmm(512x128x89, 512x89x89)
#   triton_bmm_119 0.0584 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_117 0.0614 ms 95.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   bmm 0.0625 ms 93.4%
#   triton_bmm_114 0.0635 ms 91.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_116 0.0748 ms 78.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_120 0.0850 ms 68.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_123 0.0870 ms 67.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_127 0.0881 ms 66.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_124 0.1065 ms 54.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_128 0.1075 ms 54.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.2907 seconds and 0.0022 seconds precompiling
#     <div>
#
#       <progress value='1962' max='1962' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1962/1962 1:52:29, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.185500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.313100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.191000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.221200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.144300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.997000</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.729100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.575600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.476100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.338900</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.193800</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.114400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.083900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.873800</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.698300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.834000</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.739200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.586500</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.483600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.659700</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.543400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.635600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.584700</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.580100</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.581600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.493700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.675600</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.520300</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.579700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.494300</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.495200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.532700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.471800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.528800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.651700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.500400</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.667200</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.360100</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.312200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.423100</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.579500</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.379000</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.385500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.461200</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.407400</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.333800</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.465700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.464600</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.342000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.538500</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.443400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.417100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.318400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.361400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.593100</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.416900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.577900</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.488200</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.436400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.414600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.402300</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1.403200</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.425900</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.468400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.413700</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.478100</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.556900</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.394400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1.281500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.416200</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.403900</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.500000</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.426500</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.282600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.542500</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.450500</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.393200</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.588300</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.353000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.550000</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.285600</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.392500</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.469900</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>1.248400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.335400</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.257500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.307400</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.428400</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>1.336000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.362600</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.371800</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.375500</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.486000</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.509700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.543700</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>1.526100</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>1.355400</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.371500</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.381400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.394900</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.397200</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.339800</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>1.268800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.432500</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>1.420300</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.319600</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.295100</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.380500</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.432400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.268100</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.341200</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.475600</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.295100</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.496800</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>1.340800</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.326700</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.297700</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.263600</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>1.402000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.372400</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.460100</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.283700</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>1.319000</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>1.245400</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.314800</td>
#     </tr>
#     <tr>
#       <td>
# AUTOTUNE bmm(512x128x128, 512x128x128)
#   bmm 0.0594 ms 100.0%
#   triton_bmm_166 0.0707 ms 84.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_162 0.0788 ms 75.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_165 0.0799 ms 74.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_157 0.0809 ms 73.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_167 0.0860 ms 69.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   triton_bmm_170 0.0870 ms 68.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_158 0.0881 ms 67.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_161 0.0963 ms 61.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_155 0.1034 ms 57.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.2827 seconds and 0.1627 seconds precompiling
# AUTOTUNE bmm(512x128x128, 512x128x128)
#   bmm 0.0522 ms 100.0%
#   triton_bmm_233 0.0809 ms 64.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_243 0.0911 ms 57.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   triton_bmm_230 0.1106 ms 47.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_228 0.1157 ms 45.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_237 0.1178 ms 44.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_241 0.1178 ms 44.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_242 0.1311 ms 39.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_238 0.1321 ms 39.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_231 0.1434 ms 36.4% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.3484 seconds and 0.0019 seconds precompiling
# AUTOTUNE bmm(512x128x128, 512x128x128)
#   bmm 0.0543 ms 100.0%
#   triton_bmm_257 0.0655 ms 82.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_253 0.0696 ms 77.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_252 0.0707 ms 76.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_260 0.0707 ms 76.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_256 0.0727 ms 74.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_261 0.0727 ms 74.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_262 0.0758 ms 71.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   triton_bmm_265 0.0881 ms 61.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_249 0.0932 ms 58.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.2858 seconds and 0.0021 seconds precompiling
# AUTOTUNE bmm(224x67x128, 224x128x67)
#   triton_bmm_307 0.0369 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_304 0.0379 ms 97.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_318 0.0379 ms 97.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_310 0.0389 ms 94.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_314 0.0410 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_309 0.0420 ms 87.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_317 0.0440 ms 83.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   bmm 0.0461 ms 80.0%
#   triton_bmm_306 0.0471 ms 78.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_319 0.0481 ms 76.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.1681 seconds and 0.0006 seconds precompiling
# AUTOTUNE bmm(224x67x67, 224x67x128)
#   triton_bmm_337 0.0297 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_328 0.0307 ms 96.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_329 0.0317 ms 93.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_323 0.0328 ms 90.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_333 0.0328 ms 90.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_326 0.0338 ms 87.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_336 0.0338 ms 87.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_325 0.0358 ms 82.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_338 0.0369 ms 80.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=8
#   bmm 0.0389 ms 76.3%
# SingleProcess AUTOTUNE benchmarking takes 2.1629 seconds and 0.0008 seconds precompiling
# AUTOTUNE bmm(224x67x67, 224x67x128)
#   triton_bmm_380 0.0266 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_385 0.0266 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   bmm 0.0276 ms 96.3%
#   triton_bmm_382 0.0297 ms 89.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_386 0.0348 ms 76.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_383 0.0369 ms 72.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_393 0.0430 ms 61.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_389 0.0440 ms 60.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_394 0.0471 ms 56.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_390 0.0492 ms 54.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.1811 seconds and 0.0005 seconds precompiling
# AUTOTUNE bmm(224x67x128, 224x128x67)
#   triton_bmm_399 0.0307 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_405 0.0328 ms 93.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_409 0.0338 ms 90.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_404 0.0348 ms 88.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_408 0.0348 ms 88.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_401 0.0369 ms 83.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_402 0.0369 ms 83.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_412 0.0369 ms 83.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_413 0.0379 ms 81.1% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   bmm 0.0389 ms 78.9%
# SingleProcess AUTOTUNE benchmarking takes 2.1956 seconds and 0.0008 seconds precompiling
# AUTOTUNE bmm(224x128x67, 224x67x67)
#   triton_bmm_418 0.0266 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_423 0.0266 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_421 0.0307 ms 86.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   bmm 0.0328 ms 81.2%
#   triton_bmm_424 0.0348 ms 76.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_420 0.0358 ms 74.3% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_427 0.0430 ms 61.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_431 0.0440 ms 60.5% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_428 0.0492 ms 54.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_432 0.0492 ms 54.2% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=128, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 2.1852 seconds and 0.0008 seconds precompiling

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 6852.0208 seconds used for training.
# 114.2 minutes used for training.
# Peak reserved memory = 18.08 GB.
# Peak reserved memory for training = 2.871 GB.
# Peak reserved memory % of max memory = 45.706 %.
# Peak reserved memory for training % of max memory = 7.258 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference Test
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "بدي هدول الأواعي منضفين اليوم المسا.", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda") # it Converts text input into tokenized tensors and moves them to GPU (cuda).

outputs = model.generate(**inputs, max_new_tokens = 128, use_cache = True)
example_output = tokenizer.batch_decode(outputs)
example_output
# Out:
# AUTOTUNE bmm(32x41x128, 32x128x41)
#   triton_bmm_457 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_458 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_459 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_463 0.0113 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=8
#   triton_bmm_462 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_465 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_470 0.0123 ms 91.7% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_460 0.0133 ms 84.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_461 0.0133 ms 84.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_467 0.0133 ms 84.6% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 1.6701 seconds and 0.0129 seconds precompiling
# AUTOTUNE bmm(32x41x41, 32x41x128)
#   bmm 0.0102 ms 100.0%
#   triton_bmm_474 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_475 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_476 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_478 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=8
#   triton_bmm_479 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_484 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_485 0.0102 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=64, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_471 0.0113 ms 90.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=1, num_warps=2
#   triton_bmm_472 0.0113 ms 90.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 1.9181 seconds and 0.0021 seconds precompiling
# ['<bos>Translate the below text from Dialectal Arabic to Modern Standard Arabic:\n\n### DA text:\nبدي هدول الأواعي منضفين اليوم المسا.\n\n### MSA translation:\nأريد هذه الملابس أن تغسل لي هذا المساء .<eos>']

# %% [markdown]
# <a name="Run on Test Set"></a>
# ### Run on Test Set
# Run the model on Test Set and save predicted transaltions to google drive.
# The transaltions are evaluated using a seperate notwbook.

# %%
from tqdm import tqdm  # Import tqdm for progress bar

# Load tokenizer and model
FastLanguageModel.for_inference(model)  # Enable faster inference

# Load the test dataset
test_file_path = ""
test_data = pd.read_csv(test_file_path)

# Ensure 'DA' column exists
assert "DA" in test_data.columns, "Missing 'DA' column in the dataset!"

# Prepare the prompt template
alpaca_prompt = """Translate the below text from Dialectal Arabic to Modern Standard Arabic:

### DA text:
{}

### MSA:
"""

# Function for inference with progress bar
def generate_translation(da_text):
    input_text = alpaca_prompt.format(da_text)
    inputs = tokenizer([input_text], return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=128, use_cache=True)

    predicted_msa = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]

    # Extract only the generated MSA text
    return predicted_msa.split("### MSA:")[-1].strip()

# Apply inference with tqdm progress bar
tqdm.pandas(desc="Generating Translations")
test_data["Predicted MSA"] = test_data["DA"].progress_apply(generate_translation)

# Save the results
output_file_path = ""
test_data.to_csv(output_file_path, index=False)

print(f"Predicted translations saved to: {output_file_path}")
# Out:
# Generating Translations:   2%|▏         | 27/1200 [00:41<25:42,  1.32s/it]W0302 19:19:21.161000 271 torch/utils/_sympy/interp.py:159] [0/7] failed while executing pow_by_natural([VR[4, int_oo], VR[-1, -1]])
# W0302 19:19:21.175000 271 torch/utils/_sympy/interp.py:159] [0/7] failed while executing pow_by_natural([VR[4, int_oo], VR[-1, -1]])
# AUTOTUNE bmm(32x32x128, 32x128x32)
#   triton_bmm_491 0.0092 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_497 0.0092 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=4
#   triton_bmm_489 0.0102 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=128, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_495 0.0102 ms 90.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   bmm 0.0113 ms 81.8%
#   triton_bmm_490 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_492 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_493 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_494 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=64, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=4
#   triton_bmm_496 0.0113 ms 81.8% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=4
# SingleProcess AUTOTUNE benchmarking takes 1.2852 seconds and 0.0074 seconds precompiling
# AUTOTUNE bmm(32x32x32, 32x32x128)
#   bmm 0.0082 ms 100.0%
#   triton_bmm_505 0.0082 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=3, num_warps=8
#   triton_bmm_511 0.0082 ms 100.0% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
#   triton_bmm_500 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_501 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=8
#   triton_bmm_502 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=32, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_503 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=16, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_504 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=2, num_warps=4
#   triton_bmm_506 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=64, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=5, num_warps=4
#   triton_bmm_508 0.0092 ms 88.9% ACC_TYPE='tl.float32', ALLOW_TF32=False, BLOCK_K=32, BLOCK_M=32, BLOCK_N=128, B_PROLOGUE_CAST_TYPE=None, EVEN_K=False, GROUP_M=8, num_stages=4, num_warps=8
# SingleProcess AUTOTUNE benchmarking takes 1.7080 seconds and 0.0017 seconds precompiling
# Generating Translations: 100%|██████████| 1200/1200 [42:43<00:00,  2.14s/it]
# Predicted translations saved to: /content/drive/My Drive/Grad Project/Fine Tuning Predicted Translations/EXP5/exp5-gemma2-27b-test-output.csv

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")

model.push_to_hub("", token = "") # Online saving
tokenizer.push_to_hub("", token = "") # Online saving
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/457M [00:00<?, ?B/s]
# Saved model to https://huggingface.co/er-abd/lora_model_gemma2_27b_extended_gold_dataset
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/34.4M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel

    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name="lora_model",  # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length=max_seq_length,
        dtype=dtype,
        load_in_4bit=load_in_4bit,
    )
    FastLanguageModel.for_inference(model)  # Enable native 2x faster inference

# alpaca_prompt = You MUST copy from above!

inputs = tokenizer(
    [
        alpaca_prompt.format(
            "What is a famous tall tower in Paris?",  # instruction
            "",  # input
            "",  # output - leave this blank for generation!
        )
    ],
    return_tensors="pt",
).to("cuda")

outputs = model.generate(**inputs, max_new_tokens=64, use_cache=True)
tokenizer.batch_decode(outputs)
# Out:
# ['<bos>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\nWhat is a famous tall tower in Paris?\n\n### Input:\n\n\n### Response:\nThe Eiffel Tower is a famous tall tower in Paris, France. It is located on the Champ de Mars in the 7th arrondissement of Paris, on the left bank of the River Seine. The tower was designed by engineer Gustave Eiffel and his company, and was constructed from 1887 to 18']

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# This merges the LoRA adapters into the base model - Saves the full model (instead of just LoRA adapters) in 16-bit precision.
# The model is saved in the "model/" directory
# 16-bit merging reduces storage & memory usage compared to 32-bit

# save_pretrained_merged: Saves a 16-bit merged model locally.	- alloes to Load model without LoRA.
# push_to_hub_merged: Uploads the merged 16-bit model to Hugging Face.	- Share & deploy easily.


# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in llama.cpp or a UI based system like Jan or Open WebUI. You can install Jan [here](https://github.com/janhq/jan) and Open WebUI [here](https://github.com/open-webui/open-webui)
#
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Llama 3.2 Conversational notebook. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(1B_and_3B)-Conversational.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
